# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibreez16/pandas_learning/blob/main/Pandas_Practice_(1_5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import numpy as np
import pandas as pd
empty_series = pd.Series(dtype=object)
empty_series
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
ser = pd.Series([1,2,3,4,5])
series = pd.Series([6,7,8,9,10])
print(ser + series)
print(ser * series)
print(ser - series)
print(ser / series)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
ser = pd.Series([2, 4, 6, 8, 10])
series = pd.Series([1, 3, 5, 7, 10])
ser == series
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
series = pd.Series([1,2,'Python', 2.0, True, 100])
pd.to_numeric(series, errors='coerce', downcast='float')
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float32

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
run_series = pd.read_csv("/content/batsman_runs_series.csv", usecols=['batsman_run','batter'], index_col='batter' ).squeeze("columns")
run_series
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %%
run_series.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
run_series[run_series > 3000].size
# Out:
# 20

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
run_series[run_series > run_series.mean()].size
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
items_seriess = pd.read_csv('/content/items.csv', usecols=['item_name', 'item_price'], index_col='item_name').squeeze(1)
items_seriess
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
items_series[items_series.isnull()].size
# Out:
# 50

# %%
Item price is given in $, so convert it to rupees without currency symbol.

# %%
items_series = items_series.str.lstrip('$').astype(float).mul(279.0)

# %%
items_series = items_series.fillna(items_series.mean())
items_series[items_series.isnull()]
# Out:
# Series([], Name: item_price, dtype: float64)

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
items_series.mean()
# Out:
# np.float64(2082.1857874015745)

# %%
items_series.quantile([0.30, 0.06,0.5])
# Out:
# 0.30    1241.55
# 0.06     348.75
# 0.50    2441.25
# Name: item_price, dtype: float64

# %%
items_series.median()
# Out:
# 2441.25

# %%
items_seriess.hist(bins=50)
# Out:
# <Axes: >

# %%
items_series
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
items_seriess[items_series.between(1000,2000)].size
# Out:
# 553
